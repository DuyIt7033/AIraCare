# %%
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.applications import DenseNet121 
from tensorflow import keras
from sklearn.metrics import confusion_matrix, classification_report
from sklearn.utils.class_weight import compute_class_weight
from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau

IMAGE_LEN = 224
IMAGE_SIZE = (IMAGE_LEN, IMAGE_LEN)
BATCH_SIZE = 8
NUM_CLASSES = 3 

train_datagen = ImageDataGenerator(
    rescale=1./255,
    zoom_range=0.1,                
    horizontal_flip=True,          
    rotation_range=5               

)

val_test_datagen = ImageDataGenerator(
    rescale=1./255
)

train_dataset = train_datagen.flow_from_directory(
    'D:/x-ray_split/train',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=1
)

val_dataset = val_test_datagen.flow_from_directory(
    'D:/x-ray_split/val',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=1,
    shuffle=False
)

test_dataset = val_test_datagen.flow_from_directory(
    'D:/x-ray_split/test',
    target_size=IMAGE_SIZE,
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    seed=1,
    shuffle=False
)

class_names = list(train_dataset.class_indices.keys())
print("Tên các lớp:", class_names)

class_weights = compute_class_weight(
    'balanced',
    classes=np.unique(train_dataset.classes),
    y=train_dataset.classes
)
class_weights = dict(enumerate(class_weights))
print("Class Weights:", class_weights)

def build_model(num_classes):
    inputs = keras.Input(shape=(IMAGE_LEN, IMAGE_LEN, 3))

    base_model = DenseNet121(include_top=False, input_tensor=inputs, weights='imagenet')
    base_model.trainable = False 

    x = tf.keras.layers.GlobalAveragePooling2D(name='avg_pool')(base_model.output)
    x = tf.keras.layers.BatchNormalization()(x)
    x = tf.keras.layers.Dropout(0.1, name='top_dropout')(x)
    outputs = keras.layers.Dense(num_classes, activation='softmax', name='pred')(x)

    model = tf.keras.Model(inputs, outputs, name='densenet')

    optimizer = tf.keras.optimizers.Adam(learning_rate=1e-4)
    model.compile(optimizer=optimizer, loss='categorical_crossentropy', metrics=['accuracy'])

    return model

model = build_model(NUM_CLASSES)

checkpoint = ModelCheckpoint(
    filepath='E:/lv/DenseNet1/best_model.h5',
    monitor='val_accuracy',
    save_best_only=True,
    mode='max',
    verbose=1
)



lr_scheduler = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.2, 
    patience=4, 
    min_lr=1e-6,
    verbose=1
)

history = model.fit(
    train_dataset,
    validation_data=val_dataset,
    epochs=100,
    callbacks=[checkpoint, lr_scheduler],
    verbose=1,
    class_weight=class_weights  
)

plt.figure(figsize=(12, 5))

plt.subplot(1, 2, 1)
plt.plot(history.history['accuracy'], label='Training Accuracy')
plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
plt.title('Accuracy')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()

plt.subplot(1, 2, 2)
plt.plot(history.history['loss'], label='Training Loss')
plt.plot(history.history['val_loss'], label='Validation Loss')
plt.title('Loss')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()

plt.show()

# Đánh giá mô hình trên tập test
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f'Test Accuracy: {test_accuracy:.2f}')
print(f'Test Loss: {test_loss:.2f}')

# Ma trận nhầm lẫn trên tập test
true_labels = test_dataset.classes
predictions = model.predict(test_dataset)
predicted_labels = np.argmax(predictions, axis=1)
conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix (Test Set)')
plt.ylabel('Thực tế')
plt.xlabel('Dự đoán')
plt.show()

# Báo cáo phân loại chi tiết
print("Classification Report (Test Set):")
print(classification_report(true_labels, predicted_labels, target_names=class_names))

model.save('E:/lv/DenseNet1/last_model_100e.h5')
# Out:
# Found 18317 images belonging to 3 classes.
# Found 3857 images belonging to 3 classes.
# Found 1929 images belonging to 3 classes.
# Tên các lớp: ['0_normal', '1_covid19', '2_Pneumonia']
# Class Weights: {0: 0.9567011386190327, 1: 0.9559521945618704, 2: 1.1005167027156932}
# Epoch 1/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.7613 - accuracy: 0.6726
# Epoch 1: val_accuracy improved from -inf to 0.81773, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 163s 65ms/step - loss: 0.7613 - accuracy: 0.6726 - val_loss: 0.4880 - val_accuracy: 0.8177 - lr: 1.0000e-04
# Epoch 2/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.5722 - accuracy: 0.7721
# Epoch 2: val_accuracy improved from 0.81773 to 0.84833, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 144s 63ms/step - loss: 0.5722 - accuracy: 0.7721 - val_loss: 0.4153 - val_accuracy: 0.8483 - lr: 1.0000e-04
# Epoch 3/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.5280 - accuracy: 0.7964
# Epoch 3: val_accuracy improved from 0.84833 to 0.86077, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 145s 63ms/step - loss: 0.5280 - accuracy: 0.7964 - val_loss: 0.3810 - val_accuracy: 0.8608 - lr: 1.0000e-04
# Epoch 4/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4987 - accuracy: 0.8064
# Epoch 4: val_accuracy improved from 0.86077 to 0.87166, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 143s 62ms/step - loss: 0.4987 - accuracy: 0.8064 - val_loss: 0.3595 - val_accuracy: 0.8717 - lr: 1.0000e-04
# Epoch 5/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4837 - accuracy: 0.8109
# Epoch 5: val_accuracy improved from 0.87166 to 0.87425, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4837 - accuracy: 0.8109 - val_loss: 0.3470 - val_accuracy: 0.8743 - lr: 1.0000e-04
# Epoch 6/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4817 - accuracy: 0.8112
# Epoch 6: val_accuracy improved from 0.87425 to 0.87892, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4817 - accuracy: 0.8112 - val_loss: 0.3371 - val_accuracy: 0.8789 - lr: 1.0000e-04
# Epoch 7/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4733 - accuracy: 0.8171
# Epoch 7: val_accuracy improved from 0.87892 to 0.87996, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 142s 62ms/step - loss: 0.4733 - accuracy: 0.8171 - val_loss: 0.3311 - val_accuracy: 0.8800 - lr: 1.0000e-04
# Epoch 8/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4716 - accuracy: 0.8189
# Epoch 8: val_accuracy improved from 0.87996 to 0.88540, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4716 - accuracy: 0.8189 - val_loss: 0.3229 - val_accuracy: 0.8854 - lr: 1.0000e-04
# Epoch 9/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4640 - accuracy: 0.8213
# Epoch 9: val_accuracy improved from 0.88540 to 0.88955, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4640 - accuracy: 0.8214 - val_loss: 0.3171 - val_accuracy: 0.8896 - lr: 1.0000e-04
# Epoch 10/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4590 - accuracy: 0.8208
# Epoch 10: val_accuracy improved from 0.88955 to 0.89137, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 142s 62ms/step - loss: 0.4590 - accuracy: 0.8208 - val_loss: 0.3124 - val_accuracy: 0.8914 - lr: 1.0000e-04
# Epoch 11/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4648 - accuracy: 0.8224
# Epoch 11: val_accuracy improved from 0.89137 to 0.89163, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4648 - accuracy: 0.8224 - val_loss: 0.3092 - val_accuracy: 0.8916 - lr: 1.0000e-04
# Epoch 12/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4585 - accuracy: 0.8242
# Epoch 12: val_accuracy improved from 0.89163 to 0.89448, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4585 - accuracy: 0.8242 - val_loss: 0.3063 - val_accuracy: 0.8945 - lr: 1.0000e-04
# Epoch 13/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4497 - accuracy: 0.8249
# Epoch 13: val_accuracy improved from 0.89448 to 0.89551, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4497 - accuracy: 0.8249 - val_loss: 0.3055 - val_accuracy: 0.8955 - lr: 1.0000e-04
# Epoch 14/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4499 - accuracy: 0.8277
# Epoch 14: val_accuracy did not improve from 0.89551
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4499 - accuracy: 0.8277 - val_loss: 0.3018 - val_accuracy: 0.8955 - lr: 1.0000e-04
# Epoch 15/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4499 - accuracy: 0.8283
# Epoch 15: val_accuracy improved from 0.89551 to 0.89733, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 142s 62ms/step - loss: 0.4499 - accuracy: 0.8283 - val_loss: 0.3017 - val_accuracy: 0.8973 - lr: 1.0000e-04
# Epoch 16/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4442 - accuracy: 0.8299
# Epoch 16: val_accuracy improved from 0.89733 to 0.89914, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4442 - accuracy: 0.8299 - val_loss: 0.2981 - val_accuracy: 0.8991 - lr: 1.0000e-04
# Epoch 17/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4433 - accuracy: 0.8266
# Epoch 17: val_accuracy did not improve from 0.89914
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4433 - accuracy: 0.8266 - val_loss: 0.2960 - val_accuracy: 0.8991 - lr: 1.0000e-04
# Epoch 18/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4449 - accuracy: 0.8286
# Epoch 18: val_accuracy did not improve from 0.89914
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4449 - accuracy: 0.8286 - val_loss: 0.2948 - val_accuracy: 0.8973 - lr: 1.0000e-04
# Epoch 19/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4401 - accuracy: 0.8311
# Epoch 19: val_accuracy did not improve from 0.89914
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4401 - accuracy: 0.8311 - val_loss: 0.2902 - val_accuracy: 0.8991 - lr: 1.0000e-04
# Epoch 20/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4438 - accuracy: 0.8278
# Epoch 20: val_accuracy improved from 0.89914 to 0.90148, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4438 - accuracy: 0.8278 - val_loss: 0.2917 - val_accuracy: 0.9015 - lr: 1.0000e-04
# Epoch 21/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4394 - accuracy: 0.8320
# Epoch 21: val_accuracy did not improve from 0.90148
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4396 - accuracy: 0.8320 - val_loss: 0.2894 - val_accuracy: 0.9015 - lr: 1.0000e-04
# Epoch 22/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4399 - accuracy: 0.8312
# Epoch 22: val_accuracy did not improve from 0.90148
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4399 - accuracy: 0.8312 - val_loss: 0.2922 - val_accuracy: 0.8997 - lr: 1.0000e-04
# Epoch 23/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4372 - accuracy: 0.8303
# Epoch 23: val_accuracy did not improve from 0.90148
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4372 - accuracy: 0.8303 - val_loss: 0.2870 - val_accuracy: 0.9012 - lr: 1.0000e-04
# Epoch 24/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4365 - accuracy: 0.8344
# Epoch 24: val_accuracy improved from 0.90148 to 0.90511, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 143s 62ms/step - loss: 0.4365 - accuracy: 0.8344 - val_loss: 0.2865 - val_accuracy: 0.9051 - lr: 1.0000e-04
# Epoch 25/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4385 - accuracy: 0.8325
# Epoch 25: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4385 - accuracy: 0.8325 - val_loss: 0.2850 - val_accuracy: 0.9012 - lr: 1.0000e-04
# Epoch 26/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4329 - accuracy: 0.8363
# Epoch 26: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4329 - accuracy: 0.8363 - val_loss: 0.2856 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 27/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4369 - accuracy: 0.8304
# Epoch 27: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4369 - accuracy: 0.8304 - val_loss: 0.2844 - val_accuracy: 0.9030 - lr: 1.0000e-04
# Epoch 28/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4320 - accuracy: 0.8365
# Epoch 28: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4320 - accuracy: 0.8365 - val_loss: 0.2834 - val_accuracy: 0.9030 - lr: 1.0000e-04
# Epoch 29/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4329 - accuracy: 0.8344
# Epoch 29: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4329 - accuracy: 0.8344 - val_loss: 0.2855 - val_accuracy: 0.9010 - lr: 1.0000e-04
# Epoch 30/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.8364
# Epoch 30: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4305 - accuracy: 0.8364 - val_loss: 0.2825 - val_accuracy: 0.9041 - lr: 1.0000e-04
# Epoch 31/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4338 - accuracy: 0.8343
# Epoch 31: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4338 - accuracy: 0.8343 - val_loss: 0.2794 - val_accuracy: 0.9017 - lr: 1.0000e-04
# Epoch 32/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4305 - accuracy: 0.8365
# Epoch 32: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4305 - accuracy: 0.8365 - val_loss: 0.2810 - val_accuracy: 0.9023 - lr: 1.0000e-04
# Epoch 33/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4292 - accuracy: 0.8334
# Epoch 33: val_accuracy did not improve from 0.90511
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4292 - accuracy: 0.8334 - val_loss: 0.2817 - val_accuracy: 0.9036 - lr: 1.0000e-04
# Epoch 34/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4312 - accuracy: 0.8322
# Epoch 34: val_accuracy improved from 0.90511 to 0.90692, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4312 - accuracy: 0.8321 - val_loss: 0.2799 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 35/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4304 - accuracy: 0.8365
# Epoch 35: val_accuracy did not improve from 0.90692
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4304 - accuracy: 0.8365 - val_loss: 0.2781 - val_accuracy: 0.9041 - lr: 1.0000e-04
# Epoch 36/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4275 - accuracy: 0.8354
# Epoch 36: val_accuracy did not improve from 0.90692
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4275 - accuracy: 0.8354 - val_loss: 0.2771 - val_accuracy: 0.9061 - lr: 1.0000e-04
# Epoch 37/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4276 - accuracy: 0.8380
# Epoch 37: val_accuracy did not improve from 0.90692
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4276 - accuracy: 0.8380 - val_loss: 0.2772 - val_accuracy: 0.9038 - lr: 1.0000e-04
# Epoch 38/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4235 - accuracy: 0.8380
# Epoch 38: val_accuracy did not improve from 0.90692
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4235 - accuracy: 0.8380 - val_loss: 0.2793 - val_accuracy: 0.9020 - lr: 1.0000e-04
# Epoch 39/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4265 - accuracy: 0.8359
# Epoch 39: val_accuracy did not improve from 0.90692
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4265 - accuracy: 0.8359 - val_loss: 0.2761 - val_accuracy: 0.9054 - lr: 1.0000e-04
# Epoch 40/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4279 - accuracy: 0.8333
# Epoch 40: val_accuracy improved from 0.90692 to 0.90796, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4279 - accuracy: 0.8333 - val_loss: 0.2746 - val_accuracy: 0.9080 - lr: 1.0000e-04
# Epoch 41/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4237 - accuracy: 0.8370
# Epoch 41: val_accuracy did not improve from 0.90796
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4238 - accuracy: 0.8370 - val_loss: 0.2738 - val_accuracy: 0.9077 - lr: 1.0000e-04
# Epoch 42/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4282 - accuracy: 0.8359
# Epoch 42: val_accuracy improved from 0.90796 to 0.90848, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4282 - accuracy: 0.8358 - val_loss: 0.2738 - val_accuracy: 0.9085 - lr: 1.0000e-04
# Epoch 43/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4202 - accuracy: 0.8395
# Epoch 43: val_accuracy did not improve from 0.90848
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4201 - accuracy: 0.8395 - val_loss: 0.2724 - val_accuracy: 0.9059 - lr: 1.0000e-04
# Epoch 44/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4276 - accuracy: 0.8358
# Epoch 44: val_accuracy did not improve from 0.90848
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4276 - accuracy: 0.8358 - val_loss: 0.2736 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 45/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4241 - accuracy: 0.8398
# Epoch 45: val_accuracy did not improve from 0.90848
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4240 - accuracy: 0.8398 - val_loss: 0.2719 - val_accuracy: 0.9072 - lr: 1.0000e-04
# Epoch 46/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4233 - accuracy: 0.8374
# Epoch 46: val_accuracy did not improve from 0.90848
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4233 - accuracy: 0.8374 - val_loss: 0.2724 - val_accuracy: 0.9082 - lr: 1.0000e-04
# Epoch 47/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4180 - accuracy: 0.8401
# Epoch 47: val_accuracy did not improve from 0.90848
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4179 - accuracy: 0.8401 - val_loss: 0.2696 - val_accuracy: 0.9080 - lr: 1.0000e-04
# Epoch 48/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4244 - accuracy: 0.8364
# Epoch 48: val_accuracy did not improve from 0.90848
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4244 - accuracy: 0.8364 - val_loss: 0.2719 - val_accuracy: 0.9069 - lr: 1.0000e-04
# Epoch 49/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4212 - accuracy: 0.8406
# Epoch 49: val_accuracy improved from 0.90848 to 0.90926, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4212 - accuracy: 0.8406 - val_loss: 0.2705 - val_accuracy: 0.9093 - lr: 1.0000e-04
# Epoch 50/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4188 - accuracy: 0.8429
# Epoch 50: val_accuracy did not improve from 0.90926
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4187 - accuracy: 0.8429 - val_loss: 0.2708 - val_accuracy: 0.9056 - lr: 1.0000e-04
# Epoch 51/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4148 - accuracy: 0.8430
# Epoch 51: val_accuracy did not improve from 0.90926
#
# Epoch 51: ReduceLROnPlateau reducing learning rate to 1.9999999494757503e-05.
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4148 - accuracy: 0.8430 - val_loss: 0.2707 - val_accuracy: 0.9093 - lr: 1.0000e-04
# Epoch 52/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4262 - accuracy: 0.8377
# Epoch 52: val_accuracy improved from 0.90926 to 0.91029, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4262 - accuracy: 0.8377 - val_loss: 0.2685 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 53/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4121 - accuracy: 0.8455
# Epoch 53: val_accuracy did not improve from 0.91029
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4121 - accuracy: 0.8455 - val_loss: 0.2690 - val_accuracy: 0.9087 - lr: 2.0000e-05
# Epoch 54/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4168 - accuracy: 0.8413
# Epoch 54: val_accuracy did not improve from 0.91029
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4168 - accuracy: 0.8413 - val_loss: 0.2690 - val_accuracy: 0.9098 - lr: 2.0000e-05
# Epoch 55/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4122 - accuracy: 0.8426
# Epoch 55: val_accuracy improved from 0.91029 to 0.91055, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4122 - accuracy: 0.8426 - val_loss: 0.2682 - val_accuracy: 0.9106 - lr: 2.0000e-05
# Epoch 56/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4176 - accuracy: 0.8380
# Epoch 56: val_accuracy did not improve from 0.91055
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4176 - accuracy: 0.8380 - val_loss: 0.2677 - val_accuracy: 0.9095 - lr: 2.0000e-05
# Epoch 57/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4172 - accuracy: 0.8387
# Epoch 57: val_accuracy improved from 0.91055 to 0.91081, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4172 - accuracy: 0.8387 - val_loss: 0.2678 - val_accuracy: 0.9108 - lr: 2.0000e-05
# Epoch 58/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4219 - accuracy: 0.8395
# Epoch 58: val_accuracy did not improve from 0.91081
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4219 - accuracy: 0.8395 - val_loss: 0.2680 - val_accuracy: 0.9090 - lr: 2.0000e-05
# Epoch 59/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4183 - accuracy: 0.8406
# Epoch 59: val_accuracy did not improve from 0.91081
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4183 - accuracy: 0.8406 - val_loss: 0.2681 - val_accuracy: 0.9085 - lr: 2.0000e-05
# Epoch 60/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4142 - accuracy: 0.8429
# Epoch 60: val_accuracy did not improve from 0.91081
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4142 - accuracy: 0.8429 - val_loss: 0.2674 - val_accuracy: 0.9095 - lr: 2.0000e-05
# Epoch 61/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4137 - accuracy: 0.8436
# Epoch 61: val_accuracy did not improve from 0.91081
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4137 - accuracy: 0.8436 - val_loss: 0.2673 - val_accuracy: 0.9093 - lr: 2.0000e-05
# Epoch 62/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4132 - accuracy: 0.8427
# Epoch 62: val_accuracy improved from 0.91081 to 0.91107, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4132 - accuracy: 0.8427 - val_loss: 0.2667 - val_accuracy: 0.9111 - lr: 2.0000e-05
# Epoch 63/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4165 - accuracy: 0.8443
# Epoch 63: val_accuracy did not improve from 0.91107
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4165 - accuracy: 0.8444 - val_loss: 0.2682 - val_accuracy: 0.9082 - lr: 2.0000e-05
# Epoch 64/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4187 - accuracy: 0.8427
# Epoch 64: val_accuracy did not improve from 0.91107
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4187 - accuracy: 0.8427 - val_loss: 0.2675 - val_accuracy: 0.9085 - lr: 2.0000e-05
# Epoch 65/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4158 - accuracy: 0.8424
# Epoch 65: val_accuracy improved from 0.91107 to 0.91159, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4158 - accuracy: 0.8424 - val_loss: 0.2665 - val_accuracy: 0.9116 - lr: 2.0000e-05
# Epoch 66/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4232 - accuracy: 0.8379
# Epoch 66: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4232 - accuracy: 0.8379 - val_loss: 0.2669 - val_accuracy: 0.9116 - lr: 2.0000e-05
# Epoch 67/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4144 - accuracy: 0.8418
# Epoch 67: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4144 - accuracy: 0.8418 - val_loss: 0.2662 - val_accuracy: 0.9113 - lr: 2.0000e-05
# Epoch 68/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4183 - accuracy: 0.8407
# Epoch 68: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4183 - accuracy: 0.8407 - val_loss: 0.2677 - val_accuracy: 0.9093 - lr: 2.0000e-05
# Epoch 69/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4093 - accuracy: 0.8429
# Epoch 69: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4093 - accuracy: 0.8429 - val_loss: 0.2666 - val_accuracy: 0.9106 - lr: 2.0000e-05
# Epoch 70/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4196 - accuracy: 0.8397
# Epoch 70: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4196 - accuracy: 0.8397 - val_loss: 0.2667 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 71/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4170 - accuracy: 0.8390
# Epoch 71: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4169 - accuracy: 0.8391 - val_loss: 0.2661 - val_accuracy: 0.9113 - lr: 2.0000e-05
# Epoch 72/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4177 - accuracy: 0.8424
# Epoch 72: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4178 - accuracy: 0.8423 - val_loss: 0.2676 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 73/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4174 - accuracy: 0.8393
# Epoch 73: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4173 - accuracy: 0.8393 - val_loss: 0.2665 - val_accuracy: 0.9100 - lr: 2.0000e-05
# Epoch 74/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4170 - accuracy: 0.8402
# Epoch 74: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4170 - accuracy: 0.8402 - val_loss: 0.2665 - val_accuracy: 0.9106 - lr: 2.0000e-05
# Epoch 75/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4150 - accuracy: 0.8405
# Epoch 75: val_accuracy did not improve from 0.91159
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4150 - accuracy: 0.8405 - val_loss: 0.2658 - val_accuracy: 0.9111 - lr: 2.0000e-05
# Epoch 76/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4163 - accuracy: 0.8428
# Epoch 76: val_accuracy improved from 0.91159 to 0.91237, saving model to E:/lv/DenseNet1\best_model.h5
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4163 - accuracy: 0.8428 - val_loss: 0.2656 - val_accuracy: 0.9124 - lr: 2.0000e-05
# Epoch 77/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4053 - accuracy: 0.8457
# Epoch 77: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4053 - accuracy: 0.8457 - val_loss: 0.2651 - val_accuracy: 0.9103 - lr: 2.0000e-05
# Epoch 78/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4160 - accuracy: 0.8426
# Epoch 78: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4160 - accuracy: 0.8426 - val_loss: 0.2662 - val_accuracy: 0.9093 - lr: 2.0000e-05
# Epoch 79/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4149 - accuracy: 0.8396
# Epoch 79: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 140s 61ms/step - loss: 0.4148 - accuracy: 0.8396 - val_loss: 0.2669 - val_accuracy: 0.9087 - lr: 2.0000e-05
# Epoch 80/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4149 - accuracy: 0.8424
# Epoch 80: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4149 - accuracy: 0.8424 - val_loss: 0.2664 - val_accuracy: 0.9106 - lr: 2.0000e-05
# Epoch 81/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4131 - accuracy: 0.8424
# Epoch 81: val_accuracy did not improve from 0.91237
#
# Epoch 81: ReduceLROnPlateau reducing learning rate to 3.999999898951501e-06.
# 2290/2290 [==============================] - 142s 62ms/step - loss: 0.4131 - accuracy: 0.8424 - val_loss: 0.2672 - val_accuracy: 0.9098 - lr: 2.0000e-05
# Epoch 82/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4154 - accuracy: 0.8441
# Epoch 82: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 143s 62ms/step - loss: 0.4158 - accuracy: 0.8440 - val_loss: 0.2670 - val_accuracy: 0.9095 - lr: 4.0000e-06
# Epoch 83/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4135 - accuracy: 0.8431
# Epoch 83: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 148s 65ms/step - loss: 0.4135 - accuracy: 0.8431 - val_loss: 0.2671 - val_accuracy: 0.9118 - lr: 4.0000e-06
# Epoch 84/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4171 - accuracy: 0.8416
# Epoch 84: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 146s 64ms/step - loss: 0.4171 - accuracy: 0.8416 - val_loss: 0.2660 - val_accuracy: 0.9106 - lr: 4.0000e-06
# Epoch 85/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.8441
# Epoch 85: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 146s 64ms/step - loss: 0.4109 - accuracy: 0.8441 - val_loss: 0.2649 - val_accuracy: 0.9085 - lr: 4.0000e-06
# Epoch 86/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4113 - accuracy: 0.8420
# Epoch 86: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 149s 65ms/step - loss: 0.4113 - accuracy: 0.8420 - val_loss: 0.2659 - val_accuracy: 0.9085 - lr: 4.0000e-06
# Epoch 87/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4084 - accuracy: 0.8447
# Epoch 87: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 146s 64ms/step - loss: 0.4084 - accuracy: 0.8447 - val_loss: 0.2670 - val_accuracy: 0.9093 - lr: 4.0000e-06
# Epoch 88/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4051 - accuracy: 0.8446
# Epoch 88: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 149s 65ms/step - loss: 0.4051 - accuracy: 0.8446 - val_loss: 0.2651 - val_accuracy: 0.9103 - lr: 4.0000e-06
# Epoch 89/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4214 - accuracy: 0.8418
# Epoch 89: val_accuracy did not improve from 0.91237
#
# Epoch 89: ReduceLROnPlateau reducing learning rate to 1e-06.
# 2290/2290 [==============================] - 142s 62ms/step - loss: 0.4214 - accuracy: 0.8418 - val_loss: 0.2655 - val_accuracy: 0.9082 - lr: 4.0000e-06
# Epoch 90/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4081 - accuracy: 0.8432
# Epoch 90: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4080 - accuracy: 0.8432 - val_loss: 0.2668 - val_accuracy: 0.9087 - lr: 1.0000e-06
# Epoch 91/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4179 - accuracy: 0.8395
# Epoch 91: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4179 - accuracy: 0.8395 - val_loss: 0.2650 - val_accuracy: 0.9082 - lr: 1.0000e-06
# Epoch 92/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4152 - accuracy: 0.8415
# Epoch 92: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4156 - accuracy: 0.8413 - val_loss: 0.2658 - val_accuracy: 0.9095 - lr: 1.0000e-06
# Epoch 93/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4107 - accuracy: 0.8416
# Epoch 93: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4107 - accuracy: 0.8416 - val_loss: 0.2676 - val_accuracy: 0.9100 - lr: 1.0000e-06
# Epoch 94/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4112 - accuracy: 0.8415
# Epoch 94: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4112 - accuracy: 0.8415 - val_loss: 0.2650 - val_accuracy: 0.9100 - lr: 1.0000e-06
# Epoch 95/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4140 - accuracy: 0.8433
# Epoch 95: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 142s 62ms/step - loss: 0.4140 - accuracy: 0.8433 - val_loss: 0.2671 - val_accuracy: 0.9077 - lr: 1.0000e-06
# Epoch 96/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4105 - accuracy: 0.8436
# Epoch 96: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4105 - accuracy: 0.8436 - val_loss: 0.2661 - val_accuracy: 0.9100 - lr: 1.0000e-06
# Epoch 97/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4109 - accuracy: 0.8423
# Epoch 97: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4109 - accuracy: 0.8423 - val_loss: 0.2656 - val_accuracy: 0.9095 - lr: 1.0000e-06
# Epoch 98/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4141 - accuracy: 0.8402
# Epoch 98: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4141 - accuracy: 0.8401 - val_loss: 0.2653 - val_accuracy: 0.9098 - lr: 1.0000e-06
# Epoch 99/100
# 2289/2290 [============================>.] - ETA: 0s - loss: 0.4194 - accuracy: 0.8405
# Epoch 99: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 62ms/step - loss: 0.4193 - accuracy: 0.8405 - val_loss: 0.2650 - val_accuracy: 0.9116 - lr: 1.0000e-06
# Epoch 100/100
# 2290/2290 [==============================] - ETA: 0s - loss: 0.4128 - accuracy: 0.8427
# Epoch 100: val_accuracy did not improve from 0.91237
# 2290/2290 [==============================] - 141s 61ms/step - loss: 0.4128 - accuracy: 0.8427 - val_loss: 0.2652 - val_accuracy: 0.9111 - lr: 1.0000e-06
# 242/242 [==============================] - 14s 57ms/step - loss: 0.2951 - accuracy: 0.9020
# Test Accuracy: 0.90
# Test Loss: 0.30
# 242/242 [==============================] - 14s 49ms/step
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#     0_normal       0.88      0.92      0.90       672
#    1_covid19       0.93      0.92      0.92       673
#  2_Pneumonia       0.90      0.86      0.88       584
#
#     accuracy                           0.90      1929
#    macro avg       0.90      0.90      0.90      1929
# weighted avg       0.90      0.90      0.90      1929

# %%
import numpy as np
import tensorflow as tf
from tensorflow.keras.models import load_model
from sklearn.metrics import confusion_matrix, classification_report
import matplotlib.pyplot as plt
import seaborn as sns
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Định nghĩa các tham số
IMAGE_LEN = 224
IMAGE_SIZE = (IMAGE_LEN, IMAGE_LEN)
BATCH_SIZE = 8

# Tên các lớp để hiển thị kết quả
class_names = ['normal', 'covid19', 'pneumonia']  # Đảm bảo tên lớp đúng thứ tự trước đây

# Sử dụng ImageDataGenerator để tải lại tập test
val_test_datagen = ImageDataGenerator(rescale=1./255)

# Load tập test
test_dataset = val_test_datagen.flow_from_directory(
    'D:/x-ray_split/test',   
    batch_size=BATCH_SIZE,
    class_mode='categorical',
    shuffle=False  
)

model = load_model('E:/lv/DenseNet1/last_model_100e.h5')

# Đánh giá mô hình trên tập test 
test_loss, test_accuracy = model.evaluate(test_dataset)
print(f'Test Accuracy: {test_accuracy:.4f}')
print(f'Test Loss: {test_loss:.4f}')

# Dự đoán nhãn trên tập test
true_labels = test_dataset.classes
predictions = model.predict(test_dataset)
predicted_labels = np.argmax(predictions, axis=1)

# Ma trận nhầm lẫn trên tập test
conf_matrix = confusion_matrix(true_labels, predicted_labels)

plt.figure(figsize=(8, 6))
sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues', xticklabels=class_names, yticklabels=class_names)
plt.title('Confusion Matrix (Test Set)')
plt.ylabel('Thực tế')
plt.xlabel('Dự đoán')
plt.show()

print("Classification Report (Test Set):")
print(classification_report(true_labels, predicted_labels, target_names=class_names, digits=4))
# Out:
# Found 1929 images belonging to 3 classes.
# 242/242 [==============================] - 15s 53ms/step - loss: 0.2951 - accuracy: 0.9020
# Test Accuracy: 0.9020
# Test Loss: 0.2951
# 242/242 [==============================] - 14s 49ms/step
# Classification Report (Test Set):
#               precision    recall  f1-score   support
#
#       normal     0.8819    0.9226    0.9018       672
#      covid19     0.9266    0.9198    0.9232       673
#    pneumonia     0.8978    0.8579    0.8774       584
#
#     accuracy                         0.9020      1929
#    macro avg     0.9021    0.9001    0.9008      1929
# weighted avg     0.9024    0.9020    0.9019      1929
